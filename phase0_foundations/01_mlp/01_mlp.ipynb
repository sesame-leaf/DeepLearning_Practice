# %% [markdown]
# # 01_mlp

# %% [markdown]
# ## 1. Import

# %%
import torch

# %% [markdown]
# ## 2. Model Define

# %% [markdown]
# ## 3. Load Data

# %% [markdown]
# ## 4. Train Loop

# %% [markdown]
# ## 5. Result Visualize
